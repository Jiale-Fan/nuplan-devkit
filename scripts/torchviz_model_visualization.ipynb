# %%
import os
from pathlib import Path
import hydra
from nuplan.planning.script.run_training import main as main_train
from omegaconf import DictConfig
import tempfile


def visualize(sim_dict: dict) -> str:
    # Location of path with all simulation configs
    CONFIG_PATH = sim_dict['CONFIG_PATH']
    CONFIG_NAME = sim_dict['CONFIG_NAME']
    
    # add save directory
    SAVE_DIR = sim_dict['SAVE_DIR']
    # Name of the experiment
    EXPERIMENT = sim_dict['EXPERIMENT']
    JOB_NAME = sim_dict['JOB_NAME']
    TRAINING_MODEL = sim_dict['TRAINING_MODEL']
    
    # Training params
    PY_FUNC = sim_dict['PY_FUNC']
    SCENARIO_BUILDER = sim_dict['SCENARIO_BUILDER']
    SCENARIO_SELECTION = sim_dict['SCENARIO_SELECTION']
    MAX_EPOCHS = sim_dict['MAX_EPOCHS']
    BATCH_SIZE = sim_dict['BATCH_SIZE']
    
    LOG_DIR = str(Path(SAVE_DIR) / EXPERIMENT / JOB_NAME)
    print('__LOG__' + LOG_DIR)

    # Initialize configuration management system
    hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
    hydra.initialize(config_path=CONFIG_PATH)
    
    # Compose the configuration
    cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
        f'group={str(SAVE_DIR)}',
        f'cache.cache_path={str(SAVE_DIR)}/cache',
        f'experiment_name={EXPERIMENT}',
        f'job_name={JOB_NAME}',
        f'py_func={PY_FUNC}', # ['train','test','cache']
        f'+training={TRAINING_MODEL}',  # raster model that consumes ego, agents and map raster layers and regresses the ego's trajectory
        f'scenario_builder={SCENARIO_BUILDER}',  # use nuplan mini database  # ['nuplan','nuplan_challenge','nuplan_mini']
        f'scenario_filter.limit_total_scenarios={SCENARIO_SELECTION}',  # Choose 500 scenarios to train with
        'lightning.trainer.params.accelerator=ddp_spawn',  # ddp is not allowed in interactive environment, using ddp_spawn instead - this can bottleneck the data pipeline, it is recommended to run training outside the notebook
        f'lightning.trainer.params.max_epochs={MAX_EPOCHS}',
        f'data_loader.params.batch_size={BATCH_SIZE}',
        'data_loader.params.num_workers=8',
    ])
    
    # Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
    engine=main_train(cfg)
    engine.save_visualize_info('/data1/nuplan/jiale/model_vis')
    print("done. ")
    
    
if __name__ == '__main__': 
    train_dicts = []
    # # Raster Model
    # train_dicts.append(
    #     dict(
    #         # Location of path with all simulation configs
    #         CONFIG_PATH = '../nuplan/planning/script/config/training',
    #         CONFIG_NAME = 'default_training',
        
    #         # Name of the experiment
    #         EXPERIMENT = 'raster_experiment',
    #         JOB_NAME = 'raster_model',
    #         TRAINING_MODEL = 'training_raster_model',
            
    #         # Training params
    #         PY_FUNC = 'train', # ['train','test','cache']
    #         SCENARIO_BUILDER = 'nuplan_mini', # ['nuplan','nuplan_challenge','nuplan_mini']
    #         SCENARIO_SELECTION = 500,
    #         MAX_EPOCHS = 10,
    #         BATCH_SIZE = 8,
            
    #         # add save directory
    #         SAVE_DIR = '/data1/nuplan/jiale/exp'
    #     )
    # )
    # # Simple Vector Model
    # train_dicts.append(
    #     dict(
    #         # Location of path with all simulation configs
    #         CONFIG_PATH = '../nuplan/planning/script/config/training',
    #         CONFIG_NAME = 'default_training',
        
    #         # Name of the experiment
    #         EXPERIMENT = 'simple_vector_experiment',
    #         JOB_NAME = 'simple_vector_model',
    #         TRAINING_MODEL = 'training_simple_vector_model',
            
    #         # Training params
    #         PY_FUNC = 'train', # ['train','test','cache']
    #         SCENARIO_BUILDER = 'nuplan_mini', # ['nuplan','nuplan_challenge','nuplan_mini']
    #         SCENARIO_SELECTION = 500,
    #         MAX_EPOCHS = 10,
    #         BATCH_SIZE = 8,
            
    #         # add save directory
    #         SAVE_DIR = '/data1/nuplan/jiale/exp'
    #     )
    # )
    # # Vector Model
    train_dicts.append(
        dict(
            # Location of path with all simulation configs
            CONFIG_PATH = '../nuplan/planning/script/config/training',
            CONFIG_NAME = 'default_training',
        
            # Name of the experiment
            EXPERIMENT = 'vector_experiment',
            JOB_NAME = 'vector_model',
            TRAINING_MODEL = 'training_vector_model',
            
            # Training params
            PY_FUNC = 'train', # ['train','test','cache']
            SCENARIO_BUILDER = 'nuplan_mini', # ['nuplan','nuplan_challenge','nuplan_mini']
            SCENARIO_SELECTION = 20,
            MAX_EPOCHS = 1,
            BATCH_SIZE = 1,
            
            # add save directory
            SAVE_DIR = '/data1/nuplan/jiale/exp'
        )
    )

    # train_dicts.append(
    #     dict(
    #         # Location of path with all simulation configs
    #         CONFIG_PATH = '../nuplan/planning/script/config/training',
    #         CONFIG_NAME = 'default_training',
        
    #         # Name of the experiment
    #         EXPERIMENT = 'vector_experiment',
    #         JOB_NAME = 'vector_model',
    #         TRAINING_MODEL = 'training_vector_model',
            
    #         # Training params
    #         PY_FUNC = 'train', # ['train','test','cache']
    #         SCENARIO_BUILDER = 'nuplan', # ['nuplan','nuplan_challenge','nuplan_mini']
    #         SCENARIO_SELECTION = 200000, # paper: 0.2M 
    #         MAX_EPOCHS = 32,
    #         BATCH_SIZE = 8, # paper:128
            
    #         # add save directory
    #         SAVE_DIR = '/data1/nuplan/jiale/exp'
    #     )
    # )

    
    
    for train_dict in train_dicts:
        visualize(train_dict)
# Out:
# __LOG__/data1/nuplan/jiale/exp/vector_experiment/vector_model
# Global seed set to 0
# 2023-03-12 20:05:43,838 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:17}  Building experiment folders...
# 2023-03-12 20:05:43,838 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:19}  Experimental folder: /data1/nuplan/jiale/exp/vector_experiment/vector_model/2023.03.12.20.05.43
# 2023-03-12 20:05:43,839 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-03-12 20:05:43,840 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:75}  Starting ray local!
# 2023-03-12 20:05:45,827	INFO worker.py:1553 -- Started a local Ray instance.
# 2023-03-12 20:05:48,000 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-03-12 20:05:48,000 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 36
# Number of GPUs per node: 3
# Number of threads across all nodes: 36
# 2023-03-12 20:05:48,001 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-03-12 20:05:48,001 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/training/experiments/training.py:70}  Building training engine...
# 2023-03-12 20:05:48,002 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-03-12 20:05:48,220 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-03-12 20:05:48,220 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/splitter_builder.py:18}  Building Splitter...
# 2023-03-12 20:05:49,382 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/splitter_builder.py:21}  Building Splitter...DONE!
# 2023-03-12 20:05:49,383 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/data_augmentation_builder.py:19}  Building augmentors...
# 2023-03-12 20:05:49,411 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/data_augmentation_builder.py:28}  Building augmentors...DONE!
# 2023-03-12 20:05:49,411 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-03-12 20:05:49,426 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-03-12 20:05:49,427 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-03-12 20:05:49,428 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects: 100%|██████████| 36/36 [00:05<00:00,  7.07it/s]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# 2023-03-12 20:05:54,687 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/scenario_builder.py:170}  Extracted 20 scenarios for training
# 2023-03-12 20:05:54,689 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/training/experiments/training.py:81}  Updating configs based on ddp_spawn strategy is currently not supported. Optimizer and LR Scheduler configs will not be updated.
# 2023-03-12 20:05:54,696 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/training_callback_builder.py:19}  Building callbacks...
# 2023-03-12 20:05:54,716 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/builders/training_callback_builder.py:37}  Building callbacks...DONE!
# 2023-03-12 20:05:54,721 INFO {/home/jiale/Documents/master/nuplan-devkit/nuplan/planning/script/run_training.py:64}  Starting training...
# /home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'hmac-sha256' instead of '"hmac-sha256"' if you require traitlets >=5.
#   warn(
# /home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/traitlets/traitlets.py:2499: FutureWarning: Supporting extra quotes around Bytes is deprecated in traitlets 5.0. Use '876959ad-d1fe-41c2-a6ca-42200a1c0227' instead of 'b"876959ad-d1fe-41c2-a6ca-42200a1c0227"'.
#   warn(
# Traceback (most recent call last):
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/traitlets/config/application.py", line 1042, in launch_instance
#     app.initialize(argv)
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/traitlets/config/application.py", line 113, in inner
#     return method(app, *args, **kwargs)
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 678, in initialize
#     self.init_sockets()
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 317, in init_sockets
#     self.shell_port = self._bind_socket(self.shell_socket, self.shell_port)
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 252, in _bind_socket
#     return self._try_bind_socket(s, port)
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 228, in _try_bind_socket
#     s.bind("tcp://%s:%i" % (self.ip, port))
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/zmq/sugar/socket.py", line 300, in bind
#     super().bind(addr)
#   File "zmq/backend/cython/socket.pyx", line 564, in zmq.backend.cython.socket.Socket.bind
#   File "zmq/backend/cython/checkrc.pxd", line 28, in zmq.backend.cython.checkrc._check_rc
# zmq.error.ZMQError: Address already in use
# /home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'hmac-sha256' instead of '"hmac-sha256"' if you require traitlets >=5.
#   warn(
# /home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/traitlets/traitlets.py:2499: FutureWarning: Supporting extra quotes around Bytes is deprecated in traitlets 5.0. Use '876959ad-d1fe-41c2-a6ca-42200a1c0227' instead of 'b"876959ad-d1fe-41c2-a6ca-42200a1c0227"'.
#   warn(
# Traceback (most recent call last):
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/traitlets/config/application.py", line 1042, in launch_instance
#     app.initialize(argv)
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/traitlets/config/application.py", line 113, in inner
#     return method(app, *args, **kwargs)
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 678, in initialize
#     self.init_sockets()
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 317, in init_sockets
#     self.shell_port = self._bind_socket(self.shell_socket, self.shell_port)
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 252, in _bind_socket
#     return self._try_bind_socket(s, port)
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 228, in _try_bind_socket
#     s.bind("tcp://%s:%i" % (self.ip, port))
#   File "/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/zmq/sugar/socket.py", line 300, in bind
#     super().bind(addr)
#   File "zmq/backend/cython/socket.pyx", line 564, in zmq.backend.cython.socket.Socket.bind
#   File "zmq/backend/cython/checkrc.pxd", line 28, in zmq.backend.cython.checkrc._check_rc
# zmq.error.ZMQError: Address already in use
# Global seed set to 0
# initializing ddp: GLOBAL_RANK: 0, MEMBER: 1/3
# 2023-03-12 20:36:03,328 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:194}  Added key: store_based_barrier_key:1 to store for rank: 0
# 2023-03-12 20:36:13,502 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:36:23,506 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:36:33,510 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:36:43,521 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:36:53,523 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:37:03,525 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:37:13,530 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:37:23,537 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:37:33,546 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:37:43,548 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:37:53,554 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:38:03,556 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:38:13,562 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:38:23,566 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:38:33,571 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:38:43,576 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:38:53,580 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:39:03,587 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:39:13,592 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:39:23,598 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:39:33,603 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:39:43,605 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:39:53,612 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:40:03,615 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:40:13,618 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:40:23,621 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:40:33,626 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:40:43,627 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:40:53,632 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:41:03,637 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:41:13,642 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:41:23,647 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:41:33,651 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:41:43,652 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:41:53,661 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:42:03,669 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:42:13,677 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:42:23,679 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:42:33,681 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:42:43,685 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:42:53,692 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:43:03,697 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:43:13,704 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:43:23,710 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:43:33,713 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:43:43,718 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:43:53,727 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:44:03,731 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:44:13,740 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:44:23,742 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:44:33,743 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:44:43,747 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:44:53,751 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:45:03,753 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:45:13,754 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:45:23,760 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:45:33,771 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:45:43,780 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:45:53,788 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:46:03,791 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:46:13,793 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:46:23,795 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:46:33,806 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:46:43,809 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:46:53,812 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:47:03,815 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:47:13,818 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:47:23,822 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:47:33,825 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:47:43,835 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:47:53,842 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:48:03,845 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:48:13,847 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:48:23,854 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:48:33,865 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:48:43,871 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:48:53,875 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:49:03,878 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:49:13,880 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:49:23,889 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:49:33,899 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:49:43,902 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:49:53,913 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:50:03,923 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:50:13,925 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:50:23,932 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:50:33,933 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:50:43,942 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:50:53,950 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:51:03,957 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:51:13,967 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:51:23,970 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:51:33,972 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:51:43,976 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:51:53,979 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:52:03,990 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:52:13,996 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:52:24,003 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:52:34,012 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:52:44,016 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:52:54,018 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:53:04,021 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:53:14,023 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:53:24,024 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:53:34,027 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:53:44,038 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:53:54,043 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:54:04,047 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:54:14,051 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:54:24,061 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:54:34,065 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:54:44,071 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:54:54,076 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:55:04,079 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:55:14,082 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:55:24,090 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:55:34,093 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:55:44,104 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:55:54,109 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:56:04,113 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:56:14,115 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:56:24,119 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:56:34,126 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:56:44,131 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:56:54,137 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:57:04,145 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:57:14,148 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:57:24,150 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:57:34,157 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:57:44,165 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:57:54,170 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:58:04,177 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:58:14,186 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:58:24,188 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:58:34,192 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:58:44,196 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 20:58:54,207 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# ...
# 2023-03-12 21:00:24,256 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:00:34,262 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:00:44,268 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:00:54,272 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:01:04,281 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:01:14,290 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:01:24,294 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:01:34,296 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:01:44,304 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:01:54,308 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:02:04,313 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:02:14,323 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:02:24,334 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:02:34,338 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:02:44,347 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:02:54,354 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:03:04,358 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:03:14,368 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:03:24,373 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:03:34,378 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:03:44,380 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:03:54,389 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:04:04,399 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:04:14,403 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:04:24,411 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:04:34,414 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:04:44,421 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:04:54,425 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:05:04,428 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:05:14,430 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:05:24,434 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:05:34,444 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:05:44,446 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# 2023-03-12 21:05:54,456 INFO {/home/jiale/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:212}  Waiting in store based barrier to initialize process group for rank: 0, key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 155
#     129 # train_dicts.append(
#     130 #     dict(
#     131 #         # Location of path with all simulation configs
#    (...)
#     149 #     )
#     150 # )
#     154 for train_dict in train_dicts:
# --> 155     visualize(train_dict)
#
# Cell In[1], line 52, in visualize(sim_dict)
#      36 cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
#      37     f'group={str(SAVE_DIR)}',
#      38     f'cache.cache_path={str(SAVE_DIR)}/cache',
#    (...)
#      48     'data_loader.params.num_workers=8',
#      49 ])
#      51 # Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
# ---> 52 engine=main_train(cfg)
#      53 engine.save_visualize_info('/data1/nuplan/jiale/model_vis')
#      54 print("done. ")
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/hydra/main.py:44, in main.<locals>.main_decorator.<locals>.decorated_main(cfg_passthrough)
#      41 @functools.wraps(task_function)
#      42 def decorated_main(cfg_passthrough: Optional[DictConfig] = None) -> Any:
#      43     if cfg_passthrough is not None:
# ---> 44         return task_function(cfg_passthrough)
#      45     else:
#      46         args = get_args_parser()
#
# File ~/Documents/master/nuplan-devkit/nuplan/planning/script/run_training.py:66, in main(cfg)
#      64     logger.info('Starting training...')
#      65     with ProfilerContextManager(cfg.output_dir, cfg.enable_profiling, "training"):
# ---> 66         engine.trainer.fit(model=engine.model, datamodule=engine.datamodule)
#      67     return engine
#      68 elif cfg.py_func == 'test':
#      69     # Build training engine
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:460, in Trainer.fit(self, model, train_dataloader, val_dataloaders, datamodule)
#     455 # links data to the trainer
#     456 self.data_connector.attach_data(
#     457     model, train_dataloader=train_dataloader, val_dataloaders=val_dataloaders, datamodule=datamodule
#     458 )
# --> 460 self._run(model)
#     462 assert self.state.stopped
#     463 self.training = False
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:714, in Trainer._run(self, model)
#     712 self.call_hook("on_before_accelerator_backend_setup", model)
#     713 self.accelerator.connect(model)
# --> 714 self.accelerator.setup_environment()
#     715 self.call_setup_hook(model)  # allow user to setup lightning_module in accelerator environment
#     716 self.call_configure_sharded_model(model)  # allow user to setup in model sharded environment
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/pytorch_lightning/accelerators/accelerator.py:80, in Accelerator.setup_environment(self)
#      74 def setup_environment(self) -> None:
#      75     """
#      76     Setup any processes or distributed connections.
#      77     This is called before the LightningModule/DataModule setup hook
#      78     which allows the user to access the accelerator environment before setup is complete.
#      79     """
# ---> 80     self.training_type_plugin.setup_environment()
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/pytorch_lightning/plugins/training_type/ddp.py:118, in DDPPlugin.setup_environment(self)
#     115 # set the task idx
#     116 self.task_idx = self.cluster_environment.local_rank()
# --> 118 self.setup_distributed()
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/pytorch_lightning/plugins/training_type/ddp.py:206, in DDPPlugin.setup_distributed(self)
#     201 rank_zero_only.rank = self.global_rank
#     203 # set up server using proc 0's ip address
#     204 # try to init for 20 times at max in case ports are taken
#     205 # where to store ip_table
# --> 206 self.init_ddp_connection()
#     208 # set the ranks and devices
#     209 self.dist.rank = self.global_rank
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/pytorch_lightning/plugins/training_type/ddp.py:273, in DDPPlugin.init_ddp_connection(self, global_rank, world_size)
#     271 if not torch.distributed.is_initialized():
#     272     log.info(f"initializing ddp: GLOBAL_RANK: {global_rank}, MEMBER: {global_rank + 1}/{world_size}")
# --> 273     torch_distrib.init_process_group(self.torch_distributed_backend, rank=global_rank, world_size=world_size)
#     275     # on rank=0 let everyone know training is starting
#     276     rank_zero_info(
#     277         f"{'-' * 100}\n"
#     278         f"distributed_backend={self.torch_distributed_backend}\n"
#     279         f"All DDP processes registered. Starting ddp with {self.world_size} processes\n"
#     280         f"{'-' * 100}\n"
#     281     )
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:547, in init_process_group(backend, init_method, timeout, world_size, rank, store, group_name, pg_options)
#     543     barrier()
#     544 else:
#     545     # Use store based barrier here since barrier() used a bunch of
#     546     # default devices and messes up NCCL internal state.
# --> 547     _store_based_barrier(rank, store, timeout)
#     548     # Set sequence numbers for gloo and nccl process groups.
#     549     if get_backend(default_pg) in [Backend.GLOO, Backend.NCCL]:
#
# File ~/anaconda3/envs/nuplan/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:219, in _store_based_barrier(rank, store, timeout)
#     216         log_time = time.time()
#     218     if timedelta(seconds=(time.time() - start)) > timeout:
# --> 219         raise RuntimeError(
#     220             "Timed out initializing process group in store based barrier on "
#     221             "rank: {}, for key: {} (world_size={}, worker_count={}, timeout={})".format(
#     222                 rank, store_key, world_size, worker_count, timeout))
#     224 logger.info(
#     225     f"Rank {rank}: Completed store-based barrier for {world_size} nodes."
#     226 )
#
# RuntimeError: Timed out initializing process group in store based barrier on rank: 0, for key: store_based_barrier_key:1 (world_size=3, worker_count=1, timeout=0:30:00)
